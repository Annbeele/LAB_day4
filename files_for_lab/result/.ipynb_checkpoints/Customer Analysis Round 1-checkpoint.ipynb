# %% [markdown]
# ## Lab | Customer Analysis Round 1
#
# Remember the process:
#
# Case Study
# Get data
# Cleaning/Wrangling/EDA
# Processing Data
# Modeling
# Validation
# Reporting
#
# ### Abstract
#
# The objective of this data is to understand customer demographics and buying behavior. Later during the week, we will use predictive analytics to analyze the most profitable customers and how they interact. After that, we will take targeted actions to increase profitable customer response, retention, and growth.
#
# For this lab, we will gather the data from 3 csv files that are provided in the files_for_lab folder. Use that data and complete the data cleaning tasks as mentioned later in the instructions.
#
# ## Instructions
#
# Read the three files into python as dataframes
#
# Show the DataFrame's shape.
#
# Standardize header names.
#
# Rearrange the columns in the dataframe as needed
#
# Concatenate the three dataframes
#
# Which columns are numerical?
#
# Which columns are categorical?
#
# Understand the meaning of all columns
#
# Perform the data cleaning operations mentioned so far in class
#
# <li>
# Delete the column education and the number of open complaints from the dataframe.
# <li>Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
# <li>Check for duplicate rows in the data and remove if any.
# <li>Filter out the data for customers who have an income of 0 or less.
# </li>

# %%
import numpy as np

# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/annabeteta/Documents/IRONHACK/bootcamp/LAB/LAB_day4/files_for_lab/result'

# %%
file1=pd.read_csv("../csv_files/file1.csv")

# %%
file2=pd.read_csv("../csv_files/file2.csv")

# %%
file3=pd.read_csv("../csv_files/file3.csv")

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
file3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
file1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
# 3            SUV          529.881344
# 4  Four-Door Car           17.269323

# %%
file1=file1.sort_index(axis=1)

# %%
file1.head()
# Out:
#   Customer Customer Lifetime Value             Education GENDER   Income  \
# 0  RB50392                     NaN                Master    NaN      0.0
# 1  QZ44356              697953.59%              Bachelor      F      0.0
# 2  AI49188             1288743.17%              Bachelor      F  48767.0
# 3  WW63253              764586.18%              Bachelor      M      0.0
# 4  GA49547              536307.65%  High School or Below      M  36357.0
#
#    Monthly Premium Auto Number of Open Complaints     Policy Type          ST  \
# 0                1000.0                    1/0/00   Personal Auto  Washington
# 1                  94.0                    1/0/00   Personal Auto     Arizona
# 2                 108.0                    1/0/00   Personal Auto      Nevada
# 3                 106.0                    1/0/00  Corporate Auto  California
# 4                  68.0                    1/0/00   Personal Auto  Washington
#
#    Total Claim Amount  Vehicle Class
# 0            2.704934  Four-Door Car
# 1         1131.464935  Four-Door Car
# 2          566.472247   Two-Door Car
# 3          529.881344            SUV
# 4           17.269323  Four-Door Car

# %%
file2=file2.sort_index(axis=1)

# %%
file2.head()
# Out:
#   Customer Customer Lifetime Value Education GENDER  Income  \
# 0  GS98873              323912.47%  Bachelor      F   16061
# 1  CW49887              462680.11%    Master      F   79487
# 2  MY31220              899704.02%   College      F   54230
# 3  UH35128             2580706.30%   College      F   71210
# 4  WH52799              380812.21%   College      F   94903
#
#    Monthly Premium Auto Number of Open Complaints     Policy Type          ST  \
# 0                    88                    1/0/00   Personal Auto     Arizona
# 1                   114                    1/0/00    Special Auto  California
# 2                   112                    1/0/00   Personal Auto  California
# 3                   214                    1/1/00   Personal Auto      Oregon
# 4                    94                    1/0/00  Corporate Auto     Arizona
#
#    Total Claim Amount  Vehicle Class
# 0               633.6  Four-Door Car
# 1               547.2            SUV
# 2               537.6   Two-Door Car
# 3              1027.2     Luxury Car
# 4               451.2   Two-Door Car

# %%
file3=file3.sort_index(axis=1)

# %%
file3.head()
# Out:
#   Customer  Customer Lifetime Value             Education Gender  Income  \
# 0  SA25987              3479.137523  High School or Below      M       0
# 1  TB86706              2502.637401                Master      M       0
# 2  ZL73902              3265.156348              Bachelor      F   25820
# 3  KX23516              4455.843406  High School or Below      F       0
# 4  FN77294              7704.958480  High School or Below      M   30366
#
#    Monthly Premium Auto  Number of Open Complaints    Policy Type       State  \
# 0                   104                          0  Personal Auto  Washington
# 1                    66                          0  Personal Auto     Arizona
# 2                    82                          0  Personal Auto      Nevada
# 3                   121                          0  Personal Auto  California
# 4                   101                          2  Personal Auto  California
#
#    Total Claim Amount  Vehicle Class
# 0          499.200000   Two-Door Car
# 1            3.468912   Two-Door Car
# 2          393.600000  Four-Door Car
# 3          699.615192            SUV
# 4          484.800000            SUV

# %%
file1.columns=file3.columns
file2.columns=file3.columns

# %%
file1.head()
# Out:
#   Customer Customer Lifetime Value             Education Gender   Income  \
# 0  RB50392                     NaN                Master    NaN      0.0
# 1  QZ44356              697953.59%              Bachelor      F      0.0
# 2  AI49188             1288743.17%              Bachelor      F  48767.0
# 3  WW63253              764586.18%              Bachelor      M      0.0
# 4  GA49547              536307.65%  High School or Below      M  36357.0
#
#    Monthly Premium Auto Number of Open Complaints     Policy Type       State  \
# 0                1000.0                    1/0/00   Personal Auto  Washington
# 1                  94.0                    1/0/00   Personal Auto     Arizona
# 2                 108.0                    1/0/00   Personal Auto      Nevada
# 3                 106.0                    1/0/00  Corporate Auto  California
# 4                  68.0                    1/0/00   Personal Auto  Washington
#
#    Total Claim Amount  Vehicle Class
# 0            2.704934  Four-Door Car
# 1         1131.464935  Four-Door Car
# 2          566.472247   Two-Door Car
# 3          529.881344            SUV
# 4           17.269323  Four-Door Car

# %%
file2.head()
# Out:
#   Customer Customer Lifetime Value Education Gender  Income  \
# 0  GS98873              323912.47%  Bachelor      F   16061
# 1  CW49887              462680.11%    Master      F   79487
# 2  MY31220              899704.02%   College      F   54230
# 3  UH35128             2580706.30%   College      F   71210
# 4  WH52799              380812.21%   College      F   94903
#
#    Monthly Premium Auto Number of Open Complaints     Policy Type       State  \
# 0                    88                    1/0/00   Personal Auto     Arizona
# 1                   114                    1/0/00    Special Auto  California
# 2                   112                    1/0/00   Personal Auto  California
# 3                   214                    1/1/00   Personal Auto      Oregon
# 4                    94                    1/0/00  Corporate Auto     Arizona
#
#    Total Claim Amount  Vehicle Class
# 0               633.6  Four-Door Car
# 1               547.2            SUV
# 2               537.6   Two-Door Car
# 3              1027.2     Luxury Car
# 4               451.2   Two-Door Car

# %%
file3.head()
# Out:
#   Customer  Customer Lifetime Value             Education Gender  Income  \
# 0  SA25987              3479.137523  High School or Below      M       0
# 1  TB86706              2502.637401                Master      M       0
# 2  ZL73902              3265.156348              Bachelor      F   25820
# 3  KX23516              4455.843406  High School or Below      F       0
# 4  FN77294              7704.958480  High School or Below      M   30366
#
#    Monthly Premium Auto  Number of Open Complaints    Policy Type       State  \
# 0                   104                          0  Personal Auto  Washington
# 1                    66                          0  Personal Auto     Arizona
# 2                    82                          0  Personal Auto      Nevada
# 3                   121                          0  Personal Auto  California
# 4                   101                          2  Personal Auto  California
#
#    Total Claim Amount  Vehicle Class
# 0          499.200000   Two-Door Car
# 1            3.468912   Two-Door Car
# 2          393.600000  Four-Door Car
# 3          699.615192            SUV
# 4          484.800000            SUV

# %%
print(file1.columns)
print(file2.columns)
print(file3.columns)
# Out:
# Index(['Customer', 'Customer Lifetime Value', 'Education', 'Gender', 'Income',
#        'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type',
#        'State', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')
# Index(['Customer', 'Customer Lifetime Value', 'Education', 'Gender', 'Income',
#        'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type',
#        'State', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')
# Index(['Customer', 'Customer Lifetime Value', 'Education', 'Gender', 'Income',
#        'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type',
#        'State', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
data = pd.concat([file1, file2, file3])

# %%
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#       Customer Customer Lifetime Value             Education Gender   Income  \
# 0      RB50392                     NaN                Master    NaN      0.0
# 1      QZ44356              697953.59%              Bachelor      F      0.0
# 2      AI49188             1288743.17%              Bachelor      F  48767.0
# 3      WW63253              764586.18%              Bachelor      M      0.0
# 4      GA49547              536307.65%  High School or Below      M  36357.0
# ...        ...                     ...                   ...    ...      ...
# 12069  LA72316             23405.98798              Bachelor      M  71941.0
# 12070  PK87824             3096.511217               College      F  21604.0
# 12071  TD14365             8163.890428              Bachelor      M      0.0
# 12072  UP19263             7524.442436               College      M  21941.0
# 12073  Y167826             2611.836866               College      M      0.0
#
#        Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                    1000.0                    1/0/00   Personal Auto
# 1                      94.0                    1/0/00   Personal Auto
# 2                     108.0                    1/0/00   Personal Auto
# 3                     106.0                    1/0/00  Corporate Auto
# 4                      68.0                    1/0/00   Personal Auto
# ...                     ...                       ...             ...
# 12069                  73.0                         0   Personal Auto
# 12070                  79.0                         0  Corporate Auto
# 12071                  85.0                         3  Corporate Auto
# 12072                  96.0                         0   Personal Auto
# 12073                  77.0                         0  Corporate Auto
#
#             State  Total Claim Amount  Vehicle Class
# 0      Washington            2.704934  Four-Door Car
# 1         Arizona         1131.464935  Four-Door Car
# 2          Nevada          566.472247   Two-Door Car
# 3      California          529.881344            SUV
# 4      Washington           17.269323  Four-Door Car
# ...           ...                 ...            ...
# 12069  California          198.234764  Four-Door Car
# 12070  California          379.200000  Four-Door Car
# 12071  California          790.784983  Four-Door Car
# 12072  California          691.200000  Four-Door Car
# 12073  California          369.600000   Two-Door Car
#
# [12074 rows x 11 columns]

# %%
from pandas.api.types import is_numeric_dtype

for i in data.columns:
    if is_numeric_dtype(i):
        print(i)
    else:
        print("no")
# Out:
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
